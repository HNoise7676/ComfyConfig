# %%
#change runtime to gpu

# %%
# !git clone https://github.com/Comfy-Org/ComfyUI.git
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 32248, done.
# remote: Counting objects: 100% (287/287), done.
# remote: Compressing objects: 100% (144/144), done.
# remote: Total 32248 (delta 179), reused 145 (delta 143), pack-reused 31961 (from 2)
# Receiving objects: 100% (32248/32248), 77.80 MiB | 12.92 MiB/s, done.
# Resolving deltas: 100% (21901/21901), done.

# %%
# !uv pip install -r /content/ComfyUI/requirements.txt
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 89 packages in 625ms
# Prepared 16 packages in 2.87s
# Installed 16 packages in 146ms
#  + av==16.1.0
#  + comfy-aimdo==0.1.8
#  + comfy-kitchen==0.2.7
#  + comfyui-embedded-docs==0.4.1
#  + comfyui-frontend-package==1.38.13
#  + comfyui-workflow-templates==0.8.38
#  + comfyui-workflow-templates-core==0.3.136
#  + comfyui-workflow-templates-media-api==0.3.49
#  + comfyui-workflow-templates-media-image==0.3.85
#  + comfyui-workflow-templates-media-other==0.3.116
#  + comfyui-workflow-templates-media-video==0.3.45
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + spandrel==0.4.1
#  + torchsde==0.2.6
#  + trampoline==0.1.2

# %%
# !uv pip install -r /content/ComfyUI/manager_requirements.txt
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 43 packages in 159ms
# Prepared 4 packages in 318ms
# Installed 4 packages in 6ms
#  + comfyui-manager==4.1b1
#  + pygithub==2.8.1
#  + pynacl==1.6.2
#  + uv==0.10.2

# %%
# !wget https://huggingface.co/IbarakiDouji/WAI-NSFW-illustrious-SDXL/resolve/main/waiIllustriousSDXL_v160.safetensors
# !mv /content/waiIllustriousSDXL_v160.safetensors /content/ComfyUI/models/checkpoints/waiIllustriousSDXL_v160.safetensors
# Out:
# --2026-02-12 08:49:52--  https://huggingface.co/IbarakiDouji/WAI-NSFW-illustrious-SDXL/resolve/main/waiIllustriousSDXL_v160.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.202.40, 13.35.202.97, 13.35.202.34, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.40|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # custom nodes 💜

# %%
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack
# !mv /content/ComfyUI-Impact-Pack /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
#!pip install -r /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack/requirements.txt
# Out:
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 6040, done.
# remote: Counting objects: 100% (576/576), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 6040 (delta 492), reused 379 (delta 377), pack-reused 5464 (from 4)
# Receiving objects: 100% (6040/6040), 33.16 MiB | 16.49 MiB/s, done.
# Resolving deltas: 100% (3965/3965), done.

# %%
# !git clone https://github.com/ltdrdata/ComfyUI-Impact-Pack
# !mv /content/ComfyUI-Impact-Pack /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack
#!pip install -r /content/ComfyUI/custom_nodes/ComfyUI-Impact-Pack/requirements.txt
# Out:
# Cloning into 'ComfyUI-Impact-Pack'...
# remote: Enumerating objects: 6040, done.
# remote: Counting objects: 100% (576/576), done.
# remote: Compressing objects: 100% (199/199), done.
# remote: Total 6040 (delta 492), reused 379 (delta 377), pack-reused 5464 (from 4)
# Receiving objects: 100% (6040/6040), 33.16 MiB | 16.44 MiB/s, done.
# Resolving deltas: 100% (3965/3965), done.

# %%
# !git clone https://github.com/ltdrdata/ComfyUI-Inspire-Pack
# !mv /content/ComfyUI-Inspire-Pack /content/ComfyUI/custom_nodes/ComfyUI-Inspire-Pack
# !uv pip install -r /content/ComfyUI/custom_nodes/ComfyUI-Inspire-Pack/requirements.txt
# Out:
# Cloning into 'ComfyUI-Inspire-Pack'...
# remote: Enumerating objects: 1681, done.
# remote: Counting objects: 100% (408/408), done.
# remote: Compressing objects: 100% (76/76), done.
# remote: Total 1681 (delta 356), reused 342 (delta 332), pack-reused 1273 (from 2)
# Receiving objects: 100% (1681/1681), 342.79 KiB | 20.16 MiB/s, done.
# Resolving deltas: 100% (1215/1215), done.
# Using Python 3.12.12 environment at: /usr
# Audited 5 packages in 86ms

# %%
# !git clone https://github.com/kijai/ComfyUI-KJNodes
# !mv /content/ComfyUI-KJNodes /content/ComfyUI/custom_nodes/ComfyUI-KJNodes
# !uv pip install -r /content/ComfyUI/custom_nodes/ComfyUI-KJNodes/requirements.txt
# Out:
# Cloning into 'ComfyUI-KJNodes'...
# remote: Enumerating objects: 4277, done.
# remote: Counting objects: 100% (85/85), done.
# remote: Compressing objects: 100% (51/51), done.
# remote: Total 4277 (delta 49), reused 44 (delta 34), pack-reused 4192 (from 2)
# Receiving objects: 100% (4277/4277), 25.28 MiB | 16.25 MiB/s, done.
# Resolving deltas: 100% (2948/2948), done.
# Using Python 3.12.12 environment at: /usr
# Resolved 34 packages in 103ms
# Prepared 3 packages in 14ms
# Installed 3 packages in 4ms
#  + color-matcher==0.6.0
#  + ddt==1.7.2
#  + mss==10.1.0

# %%
# !git clone https://github.com/rgthree/rgthree-comfy
# !mv /content/rgthree-comfy /content/ComfyUI/custom_nodes/rgthree-comfy
# !uv pip install -r /content/ComfyUI/custom_nodes/rgthree-comfy/requirements.txt
# Out:
# Cloning into 'rgthree-comfy'...
# remote: Enumerating objects: 4678, done.
# remote: Counting objects: 100% (1601/1601), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 4678 (delta 1343), reused 1181 (delta 1181), pack-reused 3077 (from 3)
# Receiving objects: 100% (4678/4678), 4.97 MiB | 4.10 MiB/s, done.
# Resolving deltas: 100% (3469/3469), done.
# ...
# Using Python 3.12.12 environment at: /usr
# Audited in 124ms

# %%
# !git clone https://github.com/pythongosssss/ComfyUI-Custom-Scripts
# !mv /content/ComfyUI-Custom-Scripts /content/ComfyUI/custom_nodes/ComfyUI-Custom-Scripts
# Out:
# Cloning into 'ComfyUI-Custom-Scripts'...
# remote: Enumerating objects: 2339, done.
# remote: Counting objects: 100% (974/974), done.
# remote: Compressing objects: 100% (149/149), done.
# remote: Total 2339 (delta 894), reused 826 (delta 824), pack-reused 1365 (from 1)
# Receiving objects: 100% (2339/2339), 528.58 KiB | 8.96 MiB/s, done.
# Resolving deltas: 100% (1402/1402), done.

# %% [markdown]
# # Comfyui boot + connection link

# %%
# !cd /content/ComfyUI/custom_nodes ; git clone https://github.com/cosmicbuffalo/comfyui-mobile-frontend.git
# Out:
# Cloning into 'comfyui-mobile-frontend'...
# remote: Enumerating objects: 616, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (64/64), done.
# remote: Total 616 (delta 42), reused 49 (delta 27), pack-reused 524 (from 1)
# Receiving objects: 100% (616/616), 9.12 MiB | 17.79 MiB/s, done.
# Resolving deltas: 100% (298/298), done.

# %%
# !uv pip install ngrok pyngrok
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 3 packages in 101ms
# Prepared 2 packages in 56ms
# Installed 2 packages in 4ms
#  + ngrok==1.7.0
#  + pyngrok==7.5.0

# %%
from pyngrok import ngrok

# Stop all ngrok tunnels running in the current session
ngrok.kill()
print("All ngrok tunnels killed.")

# Now, try running the ngrok.connect() cell again.
# Out:
# All ngrok tunnels killed.

# %%
from pyngrok import ngrok

# 1. Set your auth token (only needs to be done once)
ngrok.set_auth_token("39M2sUKC6dBmlnN8dVjQkUOtwop_2tZkfbds7i9pGjftv4rQw")

# 2. Open the tunnel
# Use 'addr' for the port your app is running on
public_url_object = ngrok.connect(8188)
print(public_url_object.public_url)
print(f"{public_url_object.public_url}/mobile")
# Out:
# https://kaitlin-vinicultural-ela.ngrok-free.dev
# https://kaitlin-vinicultural-ela.ngrok-free.dev/mobile

# %% [markdown]
# Your connection url is right here ⬆️

# %%
# !uv run /content/ComfyUI/main.py --listen --enable-manager
# Out:
# [START] Security scan
# [DONE] Security scan
# ** ComfyUI startup time: 2026-02-12 08:53:39.548
# ** Platform: Linux
# ** Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# [PRE] ComfyUI-Manager
# Checkpoint files will always be loaded safely.
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# Found comfy_kitchen backend triton: {'available': True, 'disabled': True, 'unavailable_reason': None, 'capabilities': ['apply_rope', 'apply_rope1', 'dequantize_nvfp4', 'dequantize_per_tensor_fp8', 'quantize_nvfp4', 'quantize_per_tensor_fp8']}
# ...
