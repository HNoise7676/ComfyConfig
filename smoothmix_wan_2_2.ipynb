# %% [markdown]
# # main installation

# %%
# !git clone https://github.com/Comfy-Org/ComfyUI.git --branch "v0.15.1"
# Out:
# Cloning into 'ComfyUI'...
# remote: Enumerating objects: 33523, done.
# remote: Counting objects: 100% (112/112), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 33523 (delta 76), reused 43 (delta 43), pack-reused 33411 (from 3)
# Receiving objects: 100% (33523/33523), 79.00 MiB | 14.16 MiB/s, done.
# Resolving deltas: 100% (22857/22857), done.
# Note: switching to '3dd10a59c00248d00f0cb0ab794ff1bb9fb00a5f'.
#
# You are in 'detached HEAD' state. You can look around, make experimental
# changes and commit them, and you can discard any commits you make in this
# state without impacting any branches by switching back to a branch.
#
# If you want to create a new branch to retain commits you create, you may
# do so (now or later) by using -c with the switch command. Example:
#
#   git switch -c <new-branch-name>
#
# Or undo this operation with:
#
#   git switch -
#
# Turn off this advice by setting config variable advice.detachedHead to false

# %%
# !uv pip install -r /content/ComfyUI/requirements.txt ; uv pip install -r /content/ComfyUI/manager_requirements.txt ; uv pip install --upgrade comfyui-frontend-package==1.41.8
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 100 packages in 661ms
# Prepared 18 packages in 2.89s
# Installed 18 packages in 155ms
#  + av==16.1.0
#  + comfy-aimdo==0.2.2
#  + comfy-kitchen==0.2.7
#  + comfyui-embedded-docs==0.4.3
#  + comfyui-frontend-package==1.39.19
#  + comfyui-workflow-templates==0.9.4
#  + comfyui-workflow-templates-core==0.3.153
#  + comfyui-workflow-templates-media-api==0.3.55
#  + comfyui-workflow-templates-media-image==0.3.93
#  + comfyui-workflow-templates-media-other==0.3.127
#  + comfyui-workflow-templates-media-video==0.3.52
#  + glfw==2.10.0
#  + kornia==0.8.2
#  + kornia-rs==0.1.10
#  + pyopengl-accelerate==3.1.10
#  + spandrel==0.4.2
#  + torchsde==0.2.6
#  + trampoline==0.1.2
# Using Python 3.12.12 environment at: /usr
# Resolved 44 packages in 121ms
# Prepared 4 packages in 287ms
# Installed 4 packages in 7ms
#  + comfyui-manager==4.1b1
#  + pygithub==2.8.1
#  + pynacl==1.6.2
#  + uv==0.10.7
# Using Python 3.12.12 environment at: /usr
# ...

# %% [markdown]
# # download models

# %%
# !wget -p /content/ComfyUI/models/checkpoints/ "https://civitai.com/api/download/models/2513182?token=4fd14121a5269875df1cd26a88336478" --content-disposition  ; wget -p /content/ComfyUI/models/checkpoints/ "https://civitai.com/api/download/models/2513186?token=4fd14121a5269875df1cd26a88336478" --content-disposition
# Out:
# /content/ComfyUI/models/checkpoints/: Scheme missing.
# --2026-02-28 20:02:09--  https://civitai.com/api/download/models/2513182?token=4fd14121a5269875df1cd26a88336478
# Resolving civitai.com (civitai.com)... 104.20.38.219, 172.66.152.186, 2606:4700:10::ac42:98ba, ...
# Connecting to civitai.com (civitai.com)|104.20.38.219|:443... connected.
# HTTP request sent, awaiting response... 307 Temporary Redirect
# Location: https://civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2802661/smoothmixI2VHighV2.kgEI.safetensors?X-Amz-Expires=86400&response-content-disposition=attachment%3B%20filename%3D%22smoothMixWan2214BI2V_i2vV20High.safetensors%22&X-Amz-Algorithm=AWS4-HMAC-SHA256&X-Amz-Credential=e01358d793ad6966166af8b3064953ad/20260228/us-east-1/s3/aws4_request&X-Amz-Date=20260228T200209Z&X-Amz-SignedHeaders=host&X-Amz-Signature=45ed91e13133df36bef4a15bf3fa820de7aa913a8138bfd3ce33865fc792b748 [following]
# ...

# %%
# !mv /content/civitai-delivery-worker-prod.5ac0637cfd0766c97916cefa3764fbdf.r2.cloudflarestorage.com/model/2802661 /content/ComfyUI/models/diffusion_models

# %%
#extra models
# !cd /content/ComfyUI/models/loras ; wget "https://huggingface.co/Kijai/WanVideo_comfy/resolve/main/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors"
# !cd /content/ComfyUI/models/text_encoders/ ; wget "https://huggingface.co/chatpig/encoder/resolve/main/umt5_xxl_fp8_e4m3fn_scaled.safetensors"
# !cd /content/ComfyUI/models/vae ; wget "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/vae/wan_2.1_vae.safetensors"
# !cd /content/ComfyUI/models/clip_vision/ ; wget "https://huggingface.co/Comfy-Org/Wan_2.1_ComfyUI_repackaged/resolve/main/split_files/clip_vision/clip_vision_h.safetensors"
# Out:
# --2026-02-28 20:07:24--  https://huggingface.co/Kijai/WanVideo_comfy/resolve/main/Lightx2v/lightx2v_I2V_14B_480p_cfg_step_distill_rank128_bf16.safetensors
# Resolving huggingface.co (huggingface.co)... 13.35.202.34, 13.35.202.121, 13.35.202.40, ...
# Connecting to huggingface.co (huggingface.co)|13.35.202.34|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# ...

# %% [markdown]
# # download custom nodes

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/city96/ComfyUI-GGUF
# Out:
# Cloning into 'ComfyUI-GGUF'...
# remote: Enumerating objects: 814, done.
# remote: Counting objects: 100% (508/508), done.
# remote: Compressing objects: 100% (196/196), done.
# remote: Total 814 (delta 458), reused 312 (delta 312), pack-reused 306 (from 2)
# Receiving objects: 100% (814/814), 189.66 KiB | 17.24 MiB/s, done.
# Resolving deltas: 100% (543/543), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/kijai/ComfyUI-KJNodes
# Out:
# Cloning into 'ComfyUI-KJNodes'...
# remote: Enumerating objects: 4377, done.
# remote: Counting objects: 100% (152/152), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 4377 (delta 91), reused 61 (delta 54), pack-reused 4225 (from 2)
# Receiving objects: 100% (4377/4377), 25.35 MiB | 17.04 MiB/s, done.
# Resolving deltas: 100% (3010/3010), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/rgthree/rgthree-comfy
# Out:
# Cloning into 'rgthree-comfy'...
# remote: Enumerating objects: 4678, done.
# remote: Counting objects: 100% (1601/1601), done.
# remote: Compressing objects: 100% (420/420), done.
# remote: Total 4678 (delta 1343), reused 1181 (delta 1181), pack-reused 3077 (from 3)
# Receiving objects: 100% (4678/4678), 4.97 MiB | 9.50 MiB/s, done.
# Resolving deltas: 100% (3469/3469), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/yolain/ComfyUI-Easy-Use
# Out:
# Cloning into 'ComfyUI-Easy-Use'...
# remote: Enumerating objects: 5423, done.
# remote: Counting objects: 100% (1748/1748), done.
# remote: Compressing objects: 100% (454/454), done.
# remote: Total 5423 (delta 1440), reused 1311 (delta 1294), pack-reused 3675 (from 2)
# Receiving objects: 100% (5423/5423), 16.54 MiB | 17.09 MiB/s, done.
# Resolving deltas: 100% (3707/3707), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/Kosinkadink/ComfyUI-VideoHelperSuite
# Out:
# Cloning into 'ComfyUI-VideoHelperSuite'...
# remote: Enumerating objects: 3332, done.
# remote: Counting objects: 100% (1579/1579), done.
# remote: Compressing objects: 100% (359/359), done.
# remote: Total 3332 (delta 1449), reused 1220 (delta 1220), pack-reused 1753 (from 3)
# Receiving objects: 100% (3332/3332), 791.43 KiB | 4.66 MiB/s, done.
# Resolving deltas: 100% (1967/1967), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/kijai/ComfyUI-WanVideoWrapper
# Out:
# Cloning into 'ComfyUI-WanVideoWrapper'...
# remote: Enumerating objects: 6617, done.
# remote: Counting objects: 100% (668/668), done.
# remote: Compressing objects: 100% (325/325), done.
# remote: Total 6617 (delta 503), reused 343 (delta 343), pack-reused 5949 (from 3)
# Receiving objects: 100% (6617/6617), 34.19 MiB | 17.39 MiB/s, done.
# Resolving deltas: 100% (4493/4493), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/Smirnov75/ComfyUI-mxToolkit
# Out:
# Cloning into 'ComfyUI-mxToolkit'...
# remote: Enumerating objects: 300, done.
# remote: Counting objects: 100% (91/91), done.
# remote: Compressing objects: 100% (40/40), done.
# remote: Total 300 (delta 79), reused 51 (delta 51), pack-reused 209 (from 2)
# Receiving objects: 100% (300/300), 169.60 KiB | 379.00 KiB/s, done.
# Resolving deltas: 100% (180/180), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/melMass/comfy_mtb
# Out:
# Cloning into 'comfy_mtb'...
# remote: Enumerating objects: 3607, done.
# remote: Counting objects: 100% (1111/1111), done.
# remote: Compressing objects: 100% (332/332), done.
# remote: Total 3607 (delta 923), reused 779 (delta 779), pack-reused 2496 (from 2)
# Receiving objects: 100% (3607/3607), 7.58 MiB | 15.38 MiB/s, done.
# Resolving deltas: 100% (2215/2215), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/kijai/ComfyUI-MMAudio
# Out:
# Cloning into 'ComfyUI-MMAudio'...
# remote: Enumerating objects: 240, done.
# remote: Counting objects: 100% (92/92), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 240 (delta 65), reused 61 (delta 59), pack-reused 148 (from 1)
# Receiving objects: 100% (240/240), 100.82 KiB | 10.08 MiB/s, done.
# Resolving deltas: 100% (107/107), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/Suzie1/ComfyUI_Comfyroll_CustomNodes
# Out:
# Cloning into 'ComfyUI_Comfyroll_CustomNodes'...
# remote: Enumerating objects: 2600, done.
# remote: Counting objects: 100% (310/310), done.
# remote: Compressing objects: 100% (90/90), done.
# remote: Total 2600 (delta 267), reused 220 (delta 220), pack-reused 2290 (from 2)
# Receiving objects: 100% (2600/2600), 3.44 MiB | 11.22 MiB/s, done.
# Resolving deltas: 100% (1739/1739), done.

# %%
# !cd /content/ComfyUI/custom_nodes/ ; git clone https://github.com/GACLove/ComfyUI-VFI
# Out:
# Cloning into 'ComfyUI-VFI'...
# remote: Enumerating objects: 81, done.
# remote: Counting objects: 100% (81/81), done.
# remote: Compressing objects: 100% (52/52), done.
# remote: Total 81 (delta 37), reused 69 (delta 25), pack-reused 0 (from 0)
# Receiving objects: 100% (81/81), 296.47 KiB | 21.18 MiB/s, done.
# Resolving deltas: 100% (37/37), done.

# %% [markdown]
# # install dependencies

# %%
# !find /content/ComfyUI/custom_nodes -name "requirements.txt" -exec uv pip install -r {} \;
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 18 packages in 547ms
# Prepared 3 packages in 25ms
# Installed 3 packages in 10ms
#  + color-matcher==0.6.0
#  + ddt==1.7.2
#  + mss==10.1.0
# Using Python 3.12.12 environment at: /usr
# Resolved 85 packages in 354ms
# Prepared 4 packages in 251ms
# Installed 4 packages in 11ms
#  + clip-interrogator==0.6.0
#  + ftfy==6.3.1
#  + onnxruntime==1.24.2
#  + open-clip-torch==3.3.0
# ...
# Using Python 3.12.12 environment at: /usr
# Audited in 88ms
# Using Python 3.12.12 environment at: /usr
# Audited 2 packages in 92ms
# Using Python 3.12.12 environment at: /usr
# Resolved 11 packages in 32ms
# Prepared 1 package in 12ms
# Installed 1 package in 3ms
#  + gguf==0.18.0
# Using Python 3.12.12 environment at: /usr
# Resolved 83 packages in 106ms
# Prepared 1 package in 6ms
# Installed 1 package in 1ms
#  + torchdiffeq==0.2.5
# Using Python 3.12.12 environment at: /usr
# Resolved 68 packages in 130ms
# Prepared 10 packages in 3.97s
# ...

# %% [markdown]
# # download workflows

# %%
# !mkdir /content/ComfyUI/user/ ; mkdir /content/ComfyUI/user/default/ ; mkdir /content/ComfyUI/user/default/workflows ; cd /content/ComfyUI/user/default/workflows/ ; wget "https://raw.githubusercontent.com/HNoise7676/ComfyConfig/refs/heads/main/WAN%202.2%20Smooth%20Workflow%20v3.0%20(img2vid-txt2vid-audio%20Modified).json"
# Out:
# mkdir: cannot create directory ‘/content/ComfyUI/user/’: File exists
# mkdir: cannot create directory ‘/content/ComfyUI/user/default/’: File exists
# mkdir: cannot create directory ‘/content/ComfyUI/user/default/workflows’: File exists
# --2026-02-28 20:21:33--  https://raw.githubusercontent.com/HNoise7676/ComfyConfig/refs/heads/main/WAN%202.2%20Smooth%20Workflow%20v3.0%20(img2vid-txt2vid-audio%20Modified).json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 130016 (127K) [text/plain]
# Saving to: ‘WAN 2.2 Smooth Workflow v3.0 (img2vid-txt2vid-audio Modified).json.1’
#
# WAN 2.2 Smooth Work 100%[===================>] 126.97K  --.-KB/s    in 0.002s
#
# ...

# %% [markdown]
# # connection setup + connect link

# %%
# !uv pip install ngrok pyngrok

from pyngrok import ngrok

# Stop all ngrok tunnels running in the current session
ngrok.kill()
print("All ngrok tunnels killed.")

# Now, try running the ngrok.connect() cell again.
# Out:
# Using Python 3.12.12 environment at: /usr
# Resolved 3 packages in 25ms
# Prepared 2 packages in 44ms
# Installed 2 packages in 3ms
#  + ngrok==1.7.0
#  + pyngrok==7.5.0
# All ngrok tunnels killed.

# %%
from pyngrok import ngrok

# 1. Set your auth token (only needs to be done once)
ngrok.set_auth_token("39M2sUKC6dBmlnN8dVjQkUOtwop_2tZkfbds7i9pGjftv4rQw")

# 2. Open the tunnel
# Use 'addr' for the port your app is running on
public_url_object = ngrok.connect(8188)
print(public_url_object.public_url)
# Out:
# https://kaitlin-vinicultural-ela.ngrok-free.dev

# %% [markdown]
# # ComfyUI log (check if connection is ready !)

# %% [markdown]
# for example: `To see the GUI go to: http://0.0.0.0:8188`

# %%
# !uv run /content/ComfyUI/main.py --listen --enable-manager --preview-method "latent2rgb"
# Out:
# [START] Security scan
# [ComfyUI-Manager] Using uv as Python module for pip operations.
# Using Python 3.12.12 environment at: /usr
# [DONE] Security scan
# ** ComfyUI startup time: 2026-02-28 20:53:55.390
# ** Platform: Linux
# ** Python version: 3.12.12 (main, Oct 10 2025, 08:52:57) [GCC 11.4.0]
# ** Python executable: /usr/bin/python3
# ** ComfyUI Path: /content/ComfyUI
# ** ComfyUI Base Folder Path: /content/ComfyUI
# ** User directory: /content/ComfyUI/user
# ** ComfyUI-Manager config path: /content/ComfyUI/user/__manager/config.ini
# ** Log path: /content/ComfyUI/user/comfyui.log
# Using Python 3.12.12 environment at: /usr
# Using Python 3.12.12 environment at: /usr
# [PRE] ComfyUI-Manager
#
# Prestartup times for custom nodes:
#    0.0 seconds: /content/ComfyUI/custom_nodes/rgthree-comfy
#    0.0 seconds: /content/ComfyUI/custom_nodes/ComfyUI-Easy-Use
#
# WARNING: You need pytorch with cu130 or higher to use optimized CUDA operations.
# ...
